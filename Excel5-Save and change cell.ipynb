# %%
import pandas as pd
duong_dan_goc = r'C:\Users\DELL\Desktop\Python CAD\excel1.xlsx'
#đường dẫn tới file

vi_tri_luu = r'C:\Users\DELL\Desktop\Python CAD\excel-new.xlsx'
#đường dẫn lưu file + tên file
 
file_goc = pd.read_excel(duong_dan_goc, sheet_name=0)

file_goc['tình trạng'] = ''
#thêm cột mới tại file gốc

file_goc.loc[2, 'tình trạng'] = 'còn hàng'
#thêm thông tin thịt là còn hàng

file_goc.loc[4, 'tình trạng'] = 1000
#thêm bimbim là còn hàng
#chú ý nếu để '1000' thì sẽ lưu theo hàng thành kiểu str



file_goc.to_excel(vi_tri_luu)
#lưu file lại theo đường dẫn

file_goc.head()
# Out:
#    STT tên sản phẩm  số lượng     giá    tổng tình trạng
# 0    1     bột giặt         2  150000  300000
# 1    2       gia vị         5    5000   25000
# 2    3         thịt         3  100000  300000   còn hàng
# 3    4           cá         2  150000  300000
# 4    5      bim bim        10    5000   50000       1000
