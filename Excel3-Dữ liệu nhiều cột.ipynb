# %%
import pandas as pd

file = pd.read_excel(r'C:\Users\DELL\Desktop\Python CAD\excel1.xlsx') 


#tonghop = ['số lượng', 'giá' , 'tổng'] #lấy dữ liệu nhiều cột
#file[tonghop].sum()
#file[tonghop].mean()

#file[tonghop].describe()
#lấy dữ liệu thống kê
#file['tổng'].describe()

#file['tổng'] = '10000' #thay đổi thông số cả 1 cột
#file.head()

file['USD'] = file['tổng']/25000 #thêm mới 1 cột
file['tổng giá (k)'] = file['tổng']/1000
file['empty'] = '' #thêm cột rỗng
file.head()
# Out:
#    STT tên sản phẩm  số lượng     giá    tổng   USD  tổng giá (k) empty
# 0    1     bột giặt         2  150000  300000  12.0         300.0
# 1    2       gia vị         5    5000   25000   1.0          25.0
# 2    3         thịt         3  100000  300000  12.0         300.0
# 3    4           cá         2  150000  300000  12.0         300.0
# 4    5      bim bim        10    5000   50000   2.0          50.0
